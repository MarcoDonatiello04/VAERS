# %%
import pandas as pd

# Supponiamo che il tuo df si chiami df_final
# Verifichiamo che non ci siano casi dove DIED='Y' ma IS_SEVERE=0
errori = df_final[(df_final['DIED'] == 'Y') & (df_final['IS_SEVERE'] == 0)]

if len(errori) == 0:
    print("✅ Sanity Check superato: Tutti i decessi sono marcati come gravi.")
else:
    print(f"⚠️ Attenzione: Ci sono {len(errori)} righe incoerenti!")

# Vediamo la distribuzione delle classi
print("\nBilanciamento del dataset:")
print(df_final['IS_SEVERE'].value_counts(normalize=True) * 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       3 # Supponiamo che il tuo df si chiami df_final
#       4 # Verifichiamo che non ci siano casi dove DIED='Y' ma IS_SEVERE=0
# ----> 5 errori = df_final[(df_final['DIED'] == 'Y') & (df_final['IS_SEVERE'] == 0)]
#       7 if len(errori) == 0:
#       8     print("✅ Sanity Check superato: Tutti i decessi sono marcati come gravi.")
#
# NameError: name 'df_final' is not defined
